# %% [markdown]
# # Big Data Project 03:
# **C) Queastion answering chatbot**
#
# *Group members:*
#
#                    Fatemeh Hoseini Sadi
#                    Alireza Keivanimehr
#                    Mehdi Falsafi

# %% [markdown]
# ### **NOTE:** Runtime must be on T4 GPU otherwise you come across an error

# %%
import os
import gdown
import shutil

file_id = '1GTUDW_wOYo2kW-dcfN5T6ygMArkcRX1F'
url = f'https://drive.google.com/uc?id={file_id}'
output = 'chatbot.rar'
gdown.download(url, output, quiet=False)

# %%
# !unrar x "/content/chatbot.rar"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/chatbot.rar
#
#   OK
#   OK
# Creating    config                                                    OK
#   OK
# Creating    data                                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# !python '/content/data/prepare.py'
# Out:
# length of dataset in characters: 3,668,541
# all the unique characters:
#  !#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]_`abcdefghijklmnopqrstuvwxyz{|}~¢£§­®°±·ÁÉ×ØàáâãäæçèéêëíïðñóôöøùúûüĀāąćčĐēīłňōŚşšūƎưǎɔɪʌʔʻʾʿˀˈάέήίαβγεζηθικλμνξοπρςστυφχψωόύώАаклсяאבדהוזחטילםמןקרשरशी्ชมยรวศาิีเምሴḥṭạảấễệốồộờủỹἀἈἐἱἸὁὐὰὶὸὺ‐–—‘’“”†•‰′⁄€−≈≤≥┌┐★♀♂♋♙♟がなひらカタナ一劉勝圖安小李萬言龍원학
# vocab size: 294
# train has 3,301,686 tokens
# val has 366,855 tokens

# %% [markdown]
# ### Run this cell if you want to train the model and see the results.

# %%
# !python '/content/train.py' --batch_size=32 --compile=False
# Out:
# Overriding: batch_size = 32
# Overriding: compile = False
# tokens per iteration will be: 327,680
# found vocab_size = 294 (inside data/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 10.73M
# num decayed parameter tensors: 26, with 10,828,032 parameters
# num non-decayed parameter tensors: 13, with 4,992 parameters
# using fused AdamW: True
# step 0: train loss 5.8141, val loss 5.8178
# iter 0: loss 5.8291, time 3925.90ms, mfu -100.00%
# iter 1: loss 5.8155, time 1892.10ms, mfu -100.00%
# iter 2: loss 5.7348, time 2105.32ms, mfu -100.00%
# iter 3: loss 5.5797, time 2129.03ms, mfu -100.00%
# iter 4: loss 5.3705, time 2142.14ms, mfu -100.00%
# iter 5: loss 5.1387, time 2153.82ms, mfu 3.49%
# iter 6: loss 4.9118, time 2176.96ms, mfu 3.48%
# iter 7: loss 4.7425, time 2157.23ms, mfu 3.48%
# iter 8: loss 4.5830, time 2159.28ms, mfu 3.48%
# iter 9: loss 4.4752, time 2177.03ms, mfu 3.48%
# iter 10: loss 4.3462, time 2204.35ms, mfu 3.47%
# ...

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# ...

# %%
# !python sample.py
# Out:
# number of parameters: 10.73M
# Loading meta from data/meta.pkl...
#
# what did dada artists think of art in past museums	When Gazet artists under the trialy convention , Bagirmingham Adobe has been suched Trich of Würnz , Innvasia .	0
# what did dada artists think of art in past museums	Others but the first known work as the `` Open State '' from 1898 to 1788 , making the surrender championship makes its existed in large plants known as Yamama , South Langfant .	0
# what did dada artists think of art in past museums	Dada ( ) is a Greek made earlier of the mid-1980s th
# ---------------
#
# what freezes faster ? hot or cold water ?	The term `` federal '' or the `` burn-commercial surface '' is under the mid-20th century that advanced conti-particular music and popularity has been subdivided into Cuba and West Point .	0
# what freezes faster in ky wayne  to the most visite work	In other contexts setaching	0
# ...

# %% [markdown]
# ### Run this cell if you only want to see the model's results

# %%
# !pip install tiktoken
# !makedir '/content/out'


# model_id = '19cSDfBnthAlDaE3DCpJhMLPAzAEimxZC'
# url = f'https://drive.google.com/uc?id={model_id}'
# output = 'ckpt.pt'
# gdown.download(url, output, quiet=False)

# newpath = '/content/out'
# if not os.path.exists(newpath):
#     os.makedirs(newpath)

# shutil.move('/content/ckpt.pt', '/content/out')

# !python sample.py
# Out:
# /bin/bash: line 1: makedir: command not found
# Downloading...
# From (original): https://drive.google.com/uc?id=19cSDfBnthAlDaE3DCpJhMLPAzAEimxZC
# From (redirected): https://drive.google.com/uc?id=19cSDfBnthAlDaE3DCpJhMLPAzAEimxZC&confirm=t&uuid=96189753-23e0-4af2-a7d9-6e2372287962
# To: /content/ckpt.pt
# 100%|██████████| 130M/130M [00:00<00:00, 147MB/s]
# number of parameters: 10.73M
# Loading meta from data/meta.pkl...
#
# what did dada artists think of art in past museums	When Gazet artists under the trialy convention , Bagirmingham Adobe has been suched Trich of Würnz , Innvasia .	0
# what did dada artists think of art in past museums	Others but the first known work as the `` Open State '' from 1898 to 1788 , making the surrender championship makes its existed in large plants known as Yamama , South Langfant .	0
# what did dada artists think of art in past museums	Dada ( ) is a Greek made earlier of the mid-1980s th
# ---------------
#
# ...
